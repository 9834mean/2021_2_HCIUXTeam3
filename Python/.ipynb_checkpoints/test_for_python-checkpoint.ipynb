# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import os

import re
from pandas.io import json
import requests
import datetime
from datetime import datetime
from bs4 import BeautifulSoup
import bs4.element
from tqdm.notebook import tqdm
from konlpy.tag import Komoran

from sklearn.manifold import TSNE
from gensim.test.utils import common_texts
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.models.word2vec import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity
from konlpy.tag import Okt
import warnings
warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim')

# %% [markdown]
# # 함수화

# %%
def get_preprocessing_data(data) : 
    data['title_contents'] = data['title'] + " " + data['contents']
    data.drop(['date','image_url','title', 'contents'], axis = 1, inplace = True)
    # 결측치 처리 
    data = data.fillna(" ")
    
    return data 

def make_doc2vec_data(data, column, t_document=False):
    data_doc = []
    for tag, doc in zip(data.index, data[column]):
        doc = doc.split(" ")
        data_doc.append(([tag], doc))
    if t_document:
        data = [TaggedDocument(words=text, tags=tag) for tag, text in data_doc]
        return data
    else:
        return data_doc
    
def make_doc2vec_models(tagged_data, tok, vector_size=128, window = 3, epochs = 40, min_count = 0, workers = 4):
    model = Doc2Vec(tagged_data, vector_size=vector_size, window=window, epochs=epochs, min_count=min_count, workers=workers)
    model.save(f'./{tok}_news_model.doc2vec')

'''    
def make_word2vec_models() :
    model = Word2Vec(tokenized_data,  # 리스트 형태의 데이터
                 sg=1,                # 0: CBOW, 1: Skip-gram
                 vector_size=100,     # 벡터 크기
                 window=3,     # 고려할 앞뒤 폭(앞뒤 3단어)
                 min_count=3,  # 사용할 단어의 최소 빈도(3회 이하 단어 무시)
                 workers=4)    # 동시에 처리할 작업 수(코어 수와 비슷하게 설정)
'''   
    
def make_user_embedding(index_list, data_doc, model):
    model.dv = model.__dict__['docvecs']
    user = []
    user_embedding = []
    for i in index_list: 
        user.append(data_doc[i][0][0])
    for i in user:
        user_embedding.append(model.dv[i])
    user_embedding = np.array(user_embedding)
    user = np.mean(user_embedding, axis = 0)
    return user

def get_recommened_contents(user, data_doc, model):
    scores = []

    for tags, text in data_doc:
        trained_doc_vec = model.docvecs[tags[0]]
        scores.append(cosine_similarity(user.reshape(-1, 128), trained_doc_vec.reshape(-1, 128)))

    scores = np.array(scores).reshape(-1)
    scores = np.argsort(-scores)[:50]
    
    return input_data.iloc[scores, :]

def view_user_history(data):
    return data[['title_contents', 'category']]

# %% [markdown]
# # Crawling

# %%
date = str(datetime.now())
date = date[:date.rfind(':')].replace(' ', '_')
date = date.replace(':','시') + '분'
today = str(datetime.now().strftime('%Y%m%d'))
print(today)

def get_soup_obj(url):
    headers = { "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36" }
    res = requests.get(url, headers = headers)
    soup = BeautifulSoup(res.text,'lxml')
    
    return soup

def get_news_contents(url):
    soup = get_soup_obj(url)
    body = soup.find('div', class_="_article_body_contents")

    news_contents = ''
    for content in body:
        if type(content) is bs4.element.NavigableString and len(content) > 50:
            news_contents += content.strip() + ' '

    return news_contents

def get_news_info(url, s) : 
    default_img = "https://search.naver.com/search.naver?where=image&sm=tab_jum&query=naver#"
    current_page = 1     
    news_info_list = []

    for i in range (10) : 
        sec_url = url + s + "&date=" + today + "&page=" + str(current_page)
        soup = get_soup_obj(sec_url)
        lis = soup.find('ul', class_='type06_headline').find_all("li", limit=15)

        for li in lis : 
            try :
                imsigisa = li.a.attrs.get('href')
                if imsigisa!="":
                    soup2 = get_soup_obj(imsigisa)
                    lis2 = soup2.find('span', class_='end_photo_org').find_all("img", limit=15)
                    imsiurl = ""
                    for li2 in lis2 :
                        imsiurl = li2.attrs.get('src')
                else:
                    imsiurl = li.img.attrs.get('src') if li.img else default_img
            except Exception as e:
                imsiurl = li.img.attrs.get('src') if li.img else default_img

            news_info = {
            "title" : li.img.attrs.get('alt') if li.img else li.a.text.replace("\n", "").replace("\t","").replace("\r","") , 
            "date" : li.find(class_="date").text,
            "news_url" : li.a.attrs.get('href'),
            "image_url" :  imsiurl,
            "category" : s }

            try :
                news_contents = get_news_contents(news_info['news_url'])
                news_info['contents'] = news_contents
                news_info_list.append(news_info)
            except Exception as e : 
                continue
        
        current_page += 1 
    
    print(s + " 분야 크롤링 완료")    
    return news_info_list

sid = ['100', '101', '102', '103', '104', '105']
default_url = "https://news.naver.com/main/list.nhn?mode=LSD&mid=sec&sid1="
df = pd.DataFrame()

for s in sid : 
    news = get_news_info(default_url, s)
    df = df.append(news)
# Out:
# 20211124
# 100 분야 크롤링 완료
# 101 분야 크롤링 완료
# 102 분야 크롤링 완료
# 103 분야 크롤링 완료
# 104 분야 크롤링 완료
# 105 분야 크롤링 완료

# %% [markdown]
# # model and EDA

# %%
input_data = get_preprocessing_data(df)

data_doc_contents = make_doc2vec_data(input_data, 'title_contents')
data_doc_contents_tag = make_doc2vec_data(input_data, 'title_contents', t_document=True)

make_doc2vec_models(data_doc_contents_tag, tok=False)

model_contents = Doc2Vec.load('./False_news_model.doc2vec')

print(input_data['category'].value_counts())
# Out:
# 104    100
# 101    100
# 100    100
# 103    100
# 105    100
# 102     91
# Name: category, dtype: int64

# %% [markdown]
# # recommand

# %%
id = "9834min"
response = requests.get("https://hciuxteam3-default-rtdb.firebaseio.com/Users/" + id + "/UserHistory.json")
json_data = response.json()

user_category = pd.DataFrame.from_dict(json_data, orient='index')
user_category = user_category.transpose()
#print(user_category)

key_list = user_category.columns
value_list = user_category.iloc[:1,:]
user_history = pd.DataFrame()
temp_df = pd.DataFrame()

for li in key_list : 
    num = user_category[li].iloc[0]
    temp_df = input_data.loc[input_data['category']==li].sample(n=10*num,  random_state=1004)
    user_history = user_history.append(temp_df, ignore_index=True)

user = make_user_embedding(user_history.index.values.tolist(), data_doc_contents, model_contents)
result1 = get_recommened_contents(user, data_doc_contents, model_contents)
pd.DataFrame(result1.loc[:, ['category', 'title_contents']])
# Out:
#    category                                     title_contents
# 92      103  [날씨] "오늘도 추워요" 영하권 추위 지속...강원도 건조주의보 24일 중부지방 ...
# 92      104  전두환 사망 외신도 긴급 타전…'29만원 발언'도 언급 영국 로이터통신은 군사 독재...
# 92      105  '지옥', 넷플릭스 공식 집계 1위…'오징어 게임' 3위 넷플릭스는 23일(현지시간...
# 92      101  제주항공 소방안전 훈련 실시 [파이낸셜뉴스] 제주항공은 지난 23일 오후 경기도 부...
# 92      100  모두발언하는 김부겸 국무총리 (세종=뉴스1) 장수영 기자 = 김부겸 국무총리가 24...
# 54      100  “北, 오징어게임 들여온 주민 총살...시청 학생 노동교화형 5년” [헤럴드경제=이...
# 54      102  계속되는 코로나19 확산세 (서울=뉴스1) 조태형 기자 = 국내 신종 코로나바이러스...
# 2       105  청호나이스, 사회복지기관에 '업사이클링 커피비누' 전달 전달된 커피비누는 청호나이스...
# 2       102  동해시, 규제 애로 해소 우수사례 2건 선정 [KBS 강릉]행정안전부가 주관하는 적...
# 87      104  BTS, 그래미 '베스트 팝 그룹' 후보에 2년 연속 선정 아메리칸 뮤직 어워즈 대...
# 87      102  KAI, AI‧빅데이터 분석업체 지분 인수 한국항공우주산업(주)(KAI)가 23일 ...
# 87      100          [속보] 김부겸 총리 “수도권, 비상계획 발동 검토해야 할 급박한 상황”
# 87      103  [날씨] 이틀째 영하권 추위…한낮 평년 회복 오늘 아침도 영하권의 추위가 나타나고 ...
# 87      101  코로나19에 대기업 기부 활동 위축…"올해 20% 이상 줄 듯" [서울=뉴시스] 이...
# 87      105  나사, 지구 방어용 소행성 충돌 우주선 발사 미국항공우주국(NASA)이 근접한 소행...
# 3       105  포스코ICT, 기술전문가 육성 위해 인사제도 혁신 나선다 포스코ICT(대표 정덕균)...
# 3       103   국립장애인도서관, 장애인 회원에게 오디오북 서비스 무제한 제공 국립장애인도서관이 ...
# 3       102  [포토] 신규 확진자 4,116명 [이데일리 김태형 기자] 24일 오전 서울 중구 ...
# 3       104  미 공항 수하물 코너 짐 기다리는 여행객들 [뉴어크=AP/뉴시스] 23일(현지시간)...
# 3       100  개발이익 환수 강화 입법 촉구 기자회견하는 진성준 의원 [데일리안 = 박항구기자] ...

# %%
result1['category'].value_counts()
# Out:
# 104    9
# 103    9
# 105    9
# 100    9
# 101    8
# 102    6
# Name: category, dtype: int64

# %%
result2 = pd.DataFrame()
category = ['100','101','102','103','104','105']

for i in range (0,50,6) : 
    for ca in category : 
        temp_df = input_data.loc[input_data['category']==ca].sample(n=1,  random_state=32)
        result2 = result2.append(temp_df, ignore_index=True)

result2
# Out:
#                                              news_url category  \
# 0   https://news.naver.com/main/read.naver?mode=LS...      100
# 1   https://news.naver.com/main/read.naver?mode=LS...      101
# 2   https://news.naver.com/main/read.naver?mode=LS...      102
# 3   https://news.naver.com/main/read.naver?mode=LS...      103
# 4   https://news.naver.com/main/read.naver?mode=LS...      104
# 5   https://news.naver.com/main/read.naver?mode=LS...      105
# 6   https://news.naver.com/main/read.naver?mode=LS...      100
# 7   https://news.naver.com/main/read.naver?mode=LS...      101
# 8   https://news.naver.com/main/read.naver?mode=LS...      102
# 9   https://news.naver.com/main/read.naver?mode=LS...      103
# 10  https://news.naver.com/main/read.naver?mode=LS...      104
# 11  https://news.naver.com/main/read.naver?mode=LS...      105
# 12  https://news.naver.com/main/read.naver?mode=LS...      100
# 13  https://news.naver.com/main/read.naver?mode=LS...      101
# 14  https://news.naver.com/main/read.naver?mode=LS...      102
# 15  https://news.naver.com/main/read.naver?mode=LS...      103
# 16  https://news.naver.com/main/read.naver?mode=LS...      104
# 17  https://news.naver.com/main/read.naver?mode=LS...      105
# 18  https://news.naver.com/main/read.naver?mode=LS...      100
# 19  https://news.naver.com/main/read.naver?mode=LS...      101
# 20  https://news.naver.com/main/read.naver?mode=LS...      102
# 21  https://news.naver.com/main/read.naver?mode=LS...      103
# 22  https://news.naver.com/main/read.naver?mode=LS...      104
# 42  윤호중 원내대표 '문재인 정부 5년 성과와 과제 연속 토론회 축사' [서울=뉴시스]...
# 43  내년 '갱신보험료' 폭탄 예고…보험료 올렸지만 또 최대 규모 적자 ‘실손보험’ [헤...
# 44  인천시, 다음달 인천발KTX 비전선포식…“공항까지 연결” [인천=이데일리 이종일 기...
# 45  갯차 윤혜진과 떠나는 겨울여행…쿠론 '더 투어리스트' 컬렉션 공개 코오롱FnC가 전...
# 46  중국산 차량용 요소 300톤 국내 반입 해양수산부는 지난 20일 중국 천진항에서 차...
# 47  IBS, 26일 ‘새로운 발견을 위한 과학’주제 석학 강연 (대전=뉴스1) 심영석 ...
# 48  윤호중 원내대표 '문재인 정부 5년 성과와 과제 연속 토론회 축사' [서울=뉴시스]...
# 49  내년 '갱신보험료' 폭탄 예고…보험료 올렸지만 또 최대 규모 적자 ‘실손보험’ [헤...
# 50  인천시, 다음달 인천발KTX 비전선포식…“공항까지 연결” [인천=이데일리 이종일 기...
# 51  갯차 윤혜진과 떠나는 겨울여행…쿠론 '더 투어리스트' 컬렉션 공개 코오롱FnC가 전...
# 52  중국산 차량용 요소 300톤 국내 반입 해양수산부는 지난 20일 중국 천진항에서 차...
# 53  IBS, 26일 ‘새로운 발견을 위한 과학’주제 석학 강연 (대전=뉴스1) 심영석 ...

# %%
result = pd.concat([result1, result2])
result
# Out:
#                                              news_url category  \
# 92  https://news.naver.com/main/read.naver?mode=LS...      103
# 92  https://news.naver.com/main/read.naver?mode=LS...      104
# 92  https://news.naver.com/main/read.naver?mode=LS...      105
# 92  https://news.naver.com/main/read.naver?mode=LS...      101
# 92  https://news.naver.com/main/read.naver?mode=LS...      100
# ..                                                ...      ...
# 49  https://news.naver.com/main/read.naver?mode=LS...      101
# 50  https://news.naver.com/main/read.naver?mode=LS...      102
# 51  https://news.naver.com/main/read.naver?mode=LS...      103
# 52  https://news.naver.com/main/read.naver?mode=LS...      104
# 53  https://news.naver.com/main/read.naver?mode=LS...      105
#
#                                        title_contents
# 92  [날씨] "오늘도 추워요" 영하권 추위 지속...강원도 건조주의보 24일 중부지방 ...
# 92  전두환 사망 외신도 긴급 타전…'29만원 발언'도 언급 영국 로이터통신은 군사 독재...
# 92  '지옥', 넷플릭스 공식 집계 1위…'오징어 게임' 3위 넷플릭스는 23일(현지시간...
# 92  제주항공 소방안전 훈련 실시 [파이낸셜뉴스] 제주항공은 지난 23일 오후 경기도 부...
# 92  모두발언하는 김부겸 국무총리 (세종=뉴스1) 장수영 기자 = 김부겸 국무총리가 24...
# ..                                                ...
# 49  내년 '갱신보험료' 폭탄 예고…보험료 올렸지만 또 최대 규모 적자 ‘실손보험’ [헤...
# 50  인천시, 다음달 인천발KTX 비전선포식…“공항까지 연결” [인천=이데일리 이종일 기...
# 51  갯차 윤혜진과 떠나는 겨울여행…쿠론 '더 투어리스트' 컬렉션 공개 코오롱FnC가 전...
# 52  중국산 차량용 요소 300톤 국내 반입 해양수산부는 지난 20일 중국 천진항에서 차...
# 53  IBS, 26일 ‘새로운 발견을 위한 과학’주제 석학 강연 (대전=뉴스1) 심영석 ...
#
# [104 rows x 3 columns]
